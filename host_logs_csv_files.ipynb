# %% [markdown]
# <a href="https://colab.research.google.com/github/AbuuIbtisaam/colab-research-space/blob/main/host_logs_csv_files.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
d=pd.read_csv("/content/1.csv", header=None)
df=pd.DataFrame(d)
df.columns=[
    'date',
    'time',
    'pro_id',
    'path',
    'sys_call',
    'event_id',
    'attack_cat',
    'attack_subcat',
    'label'
]
print(d)
# Out:
#                date     time  pro_id                                    path  \
# 0        11/03/2016  2:45:01    1830               /sbin/upstart-dbus-bridge
# 1        11/03/2016  2:45:06    1804                        /bin/dbus-daemon
# 2        11/03/2016  2:45:06    2133  /usr/lib/i386-linux-gnu/gconf/gconfd-2
# 3        11/03/2016  2:45:35    4528                      /usr/bin/python3.4
# 4        11/03/2016  2:45:44    1847                    /usr/bin/ibus-daemon
# ...             ...      ...     ...                                     ...
# 999996   11/03/2016  4:09:37    2110                         /usr/bin/compiz
# 999997   11/03/2016  4:04:53    2110                         /usr/bin/compiz
# 999998   11/03/2016  4:04:18    2110                         /usr/bin/compiz
# 999999   11/03/2016  4:04:53    2110                         /usr/bin/compiz
# 1000000  11/03/2016  4:10:49    2110                         /usr/bin/compiz
#
# ...

# %%
df.head()
# Out:
#          date     time  pro_id                                    path  \
# 0  11/03/2016  2:45:01    1830               /sbin/upstart-dbus-bridge
# 1  11/03/2016  2:45:06    1804                        /bin/dbus-daemon
# 2  11/03/2016  2:45:06    2133  /usr/lib/i386-linux-gnu/gconf/gconfd-2
# 3  11/03/2016  2:45:35    4528                      /usr/bin/python3.4
# 4  11/03/2016  2:45:44    1847                    /usr/bin/ibus-daemon
#
#    sys_call  event_id attack_cat attack_subcat  label
# 0       142     45354     normal        normal      0
# 1       256     45352     normal        normal      0
# 2       168     45372     normal        normal      0
# 3         3     39459     normal        normal      0
# 4       102     37263     normal        normal      0

# %%
df.tail()
# Out:
#                date     time  pro_id             path  sys_call  event_id  \
# 999996   11/03/2016  4:09:37    2110  /usr/bin/compiz       265   1426117
# 999997   11/03/2016  4:04:53    2110  /usr/bin/compiz       102   1349650
# 999998   11/03/2016  4:04:18    2110  /usr/bin/compiz       265   1337834
# 999999   11/03/2016  4:04:53    2110  /usr/bin/compiz       102   1349753
# 1000000  11/03/2016  4:10:49    2110  /usr/bin/compiz       102   1451346
#
#         attack_cat attack_subcat  label
# 999996      normal        normal      0
# 999997      normal        normal      0
# 999998      normal        normal      0
# 999999      normal        normal      0
# 1000000     normal        normal      0

# %%
df.sort_values("time",ascending=False)
# Out:
#               date     time  pro_id  \
# 999937  11/03/2016  4:21:05    1081
# 999951  11/03/2016  4:21:05    1081
# 999982  11/03/2016  4:21:05    1081
# 999972  11/03/2016  4:21:05    1081
# 999958  11/03/2016  4:21:05    1081
# ...            ...      ...     ...
# 14      11/03/2016  2:45:01    1872
# 18      11/03/2016  2:45:01    1951
# 19      11/03/2016  2:45:01    2114
# 21      11/03/2016  2:45:01    1966
# 0       11/03/2016  2:45:01    1830
#
#                                                      path  sys_call  event_id  \
# 999937                                      /usr/bin/Xorg       146   1612821
# 999951                                      /usr/bin/Xorg       146   1612892
# 999982                                      /usr/bin/Xorg       265   1612823
# 999972                                      /usr/bin/Xorg       265   1612793
# 999958                                      /usr/bin/Xorg       146   1612977
# ...

# %%
df.isna().sum()
# Out:
# date             0
# time             0
# pro_id           0
# path             0
# sys_call         0
# event_id         0
# attack_cat       0
# attack_subcat    0
# label            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0
